# %%
import pandas as pd
import numpy as np

# %%
#file path
netflix_credits = "Resources/credits(Netflix).csv"
netflix_title = "Resources/titles(Netflix).csv"
hulu_credits = "Resources/credits(Hulu).csv"
hulu_title = "Resources/titles(Hulu).csv"
hbo_credits = "Resources/credits(HBO).csv"
hbo_title = "Resources/titles(HBO).csv"

# %%
#read in csv files
net_credit_df = pd.read_csv(netflix_credits)
net_title_df = pd.read_csv(netflix_title)
hulu_credit_df = pd.read_csv(hulu_credits)
hulu_title_df = pd.read_csv(hulu_title)
hbo_credit_df = pd.read_csv(hbo_credits)
hbo_title_df = pd.read_csv(hbo_title)

# %%
net_credit_df.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
hulu_credit_df.head()
# Out:
#    person_id       id           name                  character   role
# 0      85144  ts20475    Aidy Bryant  Self - Various Characters  ACTOR
# 1      85141  ts20475    Michael Che  Self - Various Characters  ACTOR
# 2      87723  ts20475  Pete Davidson  Self - Various Characters  ACTOR
# 3      99154  ts20475      Mikey Day  Self - Various Characters  ACTOR
# 4      26921  ts20475     Colin Jost  Self - Various Characters  ACTOR

# %%
hbo_credit_df.head()
# Out:
#    person_id        id               name  \
# 0      60017  tm155702       Judy Garland
# 1      53496  tm155702         Ray Bolger
# 2      79549  tm155702         Jack Haley
# 3      79548  tm155702          Bert Lahr
# 4      60995  tm155702  Margaret Hamilton
#
#                                  character   role
# 0                             Dorothy Gale  ACTOR
# 1                         Hunk / Scarecrow  ACTOR
# 2                        Hickory / Tin Man  ACTOR
# 3                     Zeke / Cowardly Lion  ACTOR
# 4  Elmira Gulch / Wicked Witch of the West  ACTOR

# %%
net_title_df.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# 1                 R      114                           ['drama', 'crime']
# 2                 R      109  ['drama', 'action', 'thriller', 'european']
# 3                PG       91              ['fantasy', 'action', 'comedy']
# 4               NaN      150                            ['war', 'action']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# 1               ['US']      NaN  tt0075314         8.2    808582.0
# 2               ['US']      NaN  tt0068473         7.7    107673.0
# 3               ['GB']      NaN  tt0071853         8.2    534486.0
# 4         ['GB', 'US']      NaN  tt0061578         7.7     72662.0
#
#    tmdb_popularity  tmdb_score
# 0            0.600         NaN
# 1           40.965       8.179
# 2           10.010       7.300
# 3           15.461       7.811
# 4           20.398       7.600

# %%
hulu_title_df.head()
# Out:
#         id                      title  type  \
# 0  ts20475        Saturday Night Live  SHOW
# 1  ts20413                    M*A*S*H  SHOW
# 2  ts20005                I Love Lucy  SHOW
# 3  ts20669                       Taxi  SHOW
# 4  ts21049  The Mary Tyler Moore Show  SHOW
#
#                                          description  release_year  \
# 0  A late-night live television sketch comedy and...          1975
# 1  The 4077th Mobile Army Surgical Hospital is st...          1972
# 2  Cuban Bandleader Ricky Ricardo would be happy ...          1951
# 3  Louie De Palma is a cantankerous, acerbic taxi...          1978
# 4  30-year-old single Mary Richards moves to Minn...          1970
#
#   age_certification  runtime                      genres production_countries  \
# 0             TV-14       89         ['music', 'comedy']               ['US']
# 1             TV-PG       26  ['war', 'comedy', 'drama']               ['US']
# 2              TV-G       30        ['comedy', 'family']               ['US']
# 3             TV-PG       25         ['drama', 'comedy']               ['US']
# 4             TV-PG       28                  ['comedy']               ['US']
#
#    seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0     47.0  tt0072562         8.0     47910.0           54.345         6.9
# 1     11.0  tt0068098         8.4     55882.0           27.308         8.0
# 2      9.0  tt0043208         8.5     25944.0           17.088         8.1
# 3      5.0  tt0077089         7.7     13379.0           14.346         7.3
# 4      7.0  tt0065314         8.2      8692.0            9.290         7.5

# %%
hbo_title_df.head()
# Out:
#          id               title   type  \
# 0  tm155702    The Wizard of Oz  MOVIE
# 1   tm83648        Citizen Kane  MOVIE
# 2   tm77588          Casablanca  MOVIE
# 3   tm82363       The Big Sleep  MOVIE
# 4   tm84701  The Maltese Falcon  MOVIE
#
#                                          description  release_year  \
# 0  Young Dorothy finds herself in a magical world...          1939
# 1  Newspaper magnate, Charles Foster Kane is take...          1941
# 2  In Casablanca, Morocco in December 1941, a cyn...          1942
# 3  Private Investigator Philip Marlowe is hired b...          1946
# 4  A private detective takes on a case that invol...          1941
#
#   age_certification  runtime                            genres  \
# 0                 G      102             ['fantasy', 'family']
# 1                PG      119                         ['drama']
# 2                PG      102       ['drama', 'romance', 'war']
# 3               NaN      116             ['thriller', 'crime']
# 4               NaN      100  ['thriller', 'romance', 'crime']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      NaN  tt0032138         8.1    389774.0
# 1               ['US']      NaN  tt0033467         8.3    433804.0
# 2               ['US']      NaN  tt0034583         8.5    558849.0
# 3               ['US']      NaN  tt0038355         7.9     84494.0
# 4               ['US']      NaN  tt0033870         8.0    156603.0
#
#    tmdb_popularity  tmdb_score
# 0           41.442         7.6
# 1           14.383         8.0
# 2           20.087         8.2
# 3           12.911         7.7
# 4           12.788         7.8

# %%
#merge data frames
#merge Netflix first
netflix_df = pd.merge(net_credit_df, net_title_df, how='outer', on=['id','id'])
netflix_df['Netflix'] = 1
netflix_df = netflix_df.dropna(subset=['imdb_votes'])
netflix_df = netflix_df.drop(netflix_df[netflix_df["role"]=="ACTOR"].index)

#merge Hulu
hulu_df = pd.merge(hulu_credit_df, hulu_title_df, how='outer', on=['id','id'])
hulu_df["Hulu"] = 1
hulu_df = hulu_df.dropna(subset=['imdb_votes'])
# hulu_df = hulu_df.dropna(subset=['imdb_score', 'imdb_votes'])
hulu_df = hulu_df.drop(hulu_df[hulu_df["role"]=="ACTOR"].index)

#merge HBO
hbo_df = pd.merge(hbo_credit_df, hbo_title_df, how='outer', on=['id','id'])
hbo_df["HBO"] = 1
hbo_df = hbo_df.dropna(subset=['imdb_votes'])
hbo_df = hbo_df.drop(hbo_df[hbo_df["role"]=="ACTOR"].index)

#netflix_df
#hulu_df
#hbo_df

# %%
netflix_df = netflix_df.drop(["imdb_votes"], axis=1)
hulu_df = hulu_df.drop(["imdb_votes"], axis=1)
hbo_df = hbo_df.drop(['imdb_votes'], axis=1)

# %%
#merge all data frames into one
combined_df = pd.merge(pd.merge(netflix_df, hulu_df, how='outer'), hbo_df, how='outer')

# %%
# Isolate Christopher Nolan movies that are duplicates and delete them.
inception = combined_df[combined_df["title"]=="Inception"]
dunkirk = combined_df[combined_df["title"]=="Dunkirk"]
#inception
#dunkirk
combined_df.iloc[186,20]=1
combined_df.iloc[1268,20]=1
combined_df = combined_df.drop(labels=[6809, 7729], axis=0)
combined_df.head()
# Out:
#    person_id        id             name  character      role  \
# 0     3308.0   tm84618  Martin Scorsese        NaN  DIRECTOR
# 1    17727.0  tm154986     John Boorman        NaN  DIRECTOR
# 2    11475.0  tm127384      Terry Jones        NaN  DIRECTOR
# 3    11473.0  tm127384    Terry Gilliam        NaN  DIRECTOR
# 4     1063.0  tm120801   Robert Aldrich        NaN  DIRECTOR
#
#                              title   type  \
# 0                      Taxi Driver  MOVIE
# 1                      Deliverance  MOVIE
# 2  Monty Python and the Holy Grail  MOVIE
# 3  Monty Python and the Holy Grail  MOVIE
# 4                  The Dirty Dozen  MOVIE
#
#                                          description  release_year  \
# 0  A mentally unstable Vietnam War veteran works ...          1976
# 1  Intent on seeing the Cahulawassee River before...          1972
# 2  King Arthur, accompanied by his squire, recrui...          1975
# 3  King Arthur, accompanied by his squire, recrui...          1975
# 4  12 American military prisoners in World War II...          1967
#
#   age_certification  ...                                       genres  \
# 0                 R  ...                           ['drama', 'crime']
# 1                 R  ...  ['drama', 'action', 'thriller', 'european']
# 2                PG  ...              ['fantasy', 'action', 'comedy']
# 3                PG  ...              ['fantasy', 'action', 'comedy']
# 4               NaN  ...                            ['war', 'action']
#
#   production_countries seasons    imdb_id imdb_score  tmdb_popularity  \
# 0               ['US']     NaN  tt0075314        8.2           40.965
# 1               ['US']     NaN  tt0068473        7.7           10.010
# 2               ['GB']     NaN  tt0071853        8.2           15.461
# 3               ['GB']     NaN  tt0071853        8.2           15.461
# 4         ['GB', 'US']     NaN  tt0061578        7.7           20.398
#
#    tmdb_score  Netflix  Hulu  HBO
# 0       8.179      1.0   NaN  NaN
# 1       7.300      1.0   NaN  NaN
# 2       7.811      1.0   NaN  NaN
# 3       7.811      1.0   NaN  NaN
# 4       7.600      1.0   NaN  NaN
#
# [5 rows x 21 columns]

# %%
combined_df = combined_df[['id', 'Netflix', 'Hulu', 'HBO', 'title', 'type', 'age_certification', 'runtime', \
                           'name', 'role', 'release_year', 'seasons', 'imdb_score']]
combined_df
# Out:
#             id  Netflix  Hulu  HBO  \
# 0      tm84618      1.0   NaN  NaN
# 1     tm154986      1.0   NaN  NaN
# 2     tm127384      1.0   NaN  NaN
# 3     tm127384      1.0   NaN  NaN
# 4     tm120801      1.0   NaN  NaN
# ...        ...      ...   ...  ...
# 8381  ts304558      NaN   NaN  1.0
# 8382  ts320289      NaN   NaN  1.0
# 8383  ts314732      NaN   NaN  1.0
# 8384  ts309677      NaN   NaN  1.0
# 8385  ts300392      NaN   NaN  1.0
#
#                                              title   type age_certification  \
# 0                                      Taxi Driver  MOVIE                 R
# 1                                      Deliverance  MOVIE                 R
# 2                  Monty Python and the Holy Grail  MOVIE                PG
# 3                  Monty Python and the Holy Grail  MOVIE                PG
# 4                                  The Dirty Dozen  MOVIE               NaN
# ...                                            ...    ...               ...
# 8381                     NYC Epicenters 9/11➔2021½   SHOW             TV-MA
# 8382                              40 Means Nothing   SHOW               NaN
# 8383  Dolores: The Truth About the Wanninkhof Case   SHOW             TV-14
# 8384                           Level Playing Field   SHOW             TV-14
# 8385                              Through Our Eyes   SHOW               NaN
#
#       runtime             name      role  release_year  seasons  imdb_score
# 0         114  Martin Scorsese  DIRECTOR          1976      NaN         8.2
# 1         109     John Boorman  DIRECTOR          1972      NaN         7.7
# 2          91      Terry Jones  DIRECTOR          1975      NaN         8.2
# 3          91    Terry Gilliam  DIRECTOR          1975      NaN         8.2
# 4         150   Robert Aldrich  DIRECTOR          1967      NaN         7.7
# ...       ...              ...       ...           ...      ...         ...
# 8381      110              NaN       NaN          2021      1.0         7.1
# 8382       38              NaN       NaN          2021      1.0         6.1
# 8383       43              NaN       NaN          2021      1.0         7.4
# 8384       26              NaN       NaN          2021      1.0         5.5
# 8385       33              NaN       NaN          2021      1.0         6.1
#
# [8384 rows x 13 columns]

# %%
# combined_df = combined_df.dropna(subset=['imdb_score', 'age_certification', 'imdb_votes'])
# combined_df.sort_values("imdb_score")

# %%
# combined_df = combined_df[combined_df['imdb_score'] > 6.5]
# combined_df

# %%
# combined_df = combined_df[combined_df['imdb_votes'] > 10000]
# combined_df

# %%
combined_df = combined_df.fillna({"name": '--',
                    "role": '--',
                    "Netflix": 0,
                    "Hulu": 0,
                    "HBO": 0,
                    "seasons": 0})
combined_df
# Out:
#             id  Netflix  Hulu  HBO  \
# 0      tm84618      1.0   0.0  0.0
# 1     tm154986      1.0   0.0  0.0
# 2     tm127384      1.0   0.0  0.0
# 3     tm127384      1.0   0.0  0.0
# 4     tm120801      1.0   0.0  0.0
# ...        ...      ...   ...  ...
# 8381  ts304558      0.0   0.0  1.0
# 8382  ts320289      0.0   0.0  1.0
# 8383  ts314732      0.0   0.0  1.0
# 8384  ts309677      0.0   0.0  1.0
# 8385  ts300392      0.0   0.0  1.0
#
#                                              title   type age_certification  \
# 0                                      Taxi Driver  MOVIE                 R
# 1                                      Deliverance  MOVIE                 R
# 2                  Monty Python and the Holy Grail  MOVIE                PG
# 3                  Monty Python and the Holy Grail  MOVIE                PG
# 4                                  The Dirty Dozen  MOVIE               NaN
# ...                                            ...    ...               ...
# 8381                     NYC Epicenters 9/11➔2021½   SHOW             TV-MA
# 8382                              40 Means Nothing   SHOW               NaN
# 8383  Dolores: The Truth About the Wanninkhof Case   SHOW             TV-14
# 8384                           Level Playing Field   SHOW             TV-14
# 8385                              Through Our Eyes   SHOW               NaN
#
#       runtime             name      role  release_year  seasons  imdb_score
# 0         114  Martin Scorsese  DIRECTOR          1976      0.0         8.2
# 1         109     John Boorman  DIRECTOR          1972      0.0         7.7
# 2          91      Terry Jones  DIRECTOR          1975      0.0         8.2
# 3          91    Terry Gilliam  DIRECTOR          1975      0.0         8.2
# 4         150   Robert Aldrich  DIRECTOR          1967      0.0         7.7
# ...       ...              ...       ...           ...      ...         ...
# 8381      110               --        --          2021      1.0         7.1
# 8382       38               --        --          2021      1.0         6.1
# 8383       43               --        --          2021      1.0         7.4
# 8384       26               --        --          2021      1.0         5.5
# 8385       33               --        --          2021      1.0         6.1
#
# [8384 rows x 13 columns]

# %%
# duplicate_row = combined_df[combined_df.duplicated(subset=["title", "name"])]
# duplicate_row.sort_values("title")

# %%
movie_df = combined_df[combined_df["type"]=="MOVIE"]
#movie_df = movie_df.dropna(subset=['role'])
movie_df
#df = df.drop(df[df.score < 50].index)
# df.drop(df[df['Age'] < 25].index, inplace = True)
# Out:
#             id  Netflix  Hulu  HBO                                     title  \
# 0      tm84618      1.0   0.0  0.0                               Taxi Driver
# 1     tm154986      1.0   0.0  0.0                               Deliverance
# 2     tm127384      1.0   0.0  0.0           Monty Python and the Holy Grail
# 3     tm127384      1.0   0.0  0.0           Monty Python and the Holy Grail
# 4     tm120801      1.0   0.0  0.0                           The Dirty Dozen
# ...        ...      ...   ...  ...                                       ...
# 8363  tm832366      0.0   0.0  1.0  Shakira in Concert: El Dorado World Tour
# 8366  tm949799      0.0   0.0  1.0                                Territorio
# 8370  tm825662      0.0   0.0  1.0                        Return to the Moon
# 8372  tm483047      0.0   0.0  1.0                                  Sterling
# 8374  tm962124      0.0   0.0  1.0                                 Habla Now
#
#        type age_certification  runtime             name      role  \
# 0     MOVIE                 R      114  Martin Scorsese  DIRECTOR
# 1     MOVIE                 R      109     John Boorman  DIRECTOR
# 2     MOVIE                PG       91      Terry Jones  DIRECTOR
# 3     MOVIE                PG       91    Terry Gilliam  DIRECTOR
# 4     MOVIE               NaN      150   Robert Aldrich  DIRECTOR
# ...     ...               ...      ...              ...       ...
# 8363  MOVIE               NaN      122               --        --
# 8366  MOVIE               NaN       94               --        --
# 8370  MOVIE                PG        1               --        --
# 8372  MOVIE               NaN       20               --        --
# 8374  MOVIE               NaN       58               --        --
#
#       release_year  seasons  imdb_score
# 0             1976      0.0         8.2
# 1             1972      0.0         7.7
# 2             1975      0.0         8.2
# 3             1975      0.0         8.2
# 4             1967      0.0         7.7
# ...            ...      ...         ...
# 8363          2019      0.0         7.8
# 8366          2020      0.0         5.8
# 8370          2019      0.0         8.0
# 8372          2019      0.0         7.3
# 8374          2020      0.0         6.2
#
# [7085 rows x 13 columns]

# %%
show_df = combined_df[combined_df["type"]=="SHOW"]
show_df
# Out:
#             id  Netflix  Hulu  HBO  \
# 26     ts45948      1.0   0.0  0.0
# 51      ts2760      1.0   0.0  0.0
# 101    ts21034      1.0   0.0  0.0
# 102    ts21034      1.0   0.0  0.0
# 136    ts28516      1.0   0.0  0.0
# ...        ...      ...   ...  ...
# 8381  ts304558      0.0   0.0  1.0
# 8382  ts320289      0.0   0.0  1.0
# 8383  ts314732      0.0   0.0  1.0
# 8384  ts309677      0.0   0.0  1.0
# 8385  ts300392      0.0   0.0  1.0
#
#                                              title  type age_certification  \
# 26                Monty Python's Fliegender Zirkus  SHOW             TV-MA
# 51                                     Fireman Sam  SHOW              TV-Y
# 101                                       InuYasha  SHOW             TV-14
# 102                                       InuYasha  SHOW             TV-14
# 136                                         Okupas  SHOW             TV-MA
# ...                                            ...   ...               ...
# 8381                     NYC Epicenters 9/11➔2021½  SHOW             TV-MA
# 8382                              40 Means Nothing  SHOW               NaN
# 8383  Dolores: The Truth About the Wanninkhof Case  SHOW             TV-14
# 8384                           Level Playing Field  SHOW             TV-14
# 8385                              Through Our Eyes  SHOW               NaN
#
#       runtime             name      role  release_year  seasons  imdb_score
# 26         43  Ian MacNaughton  DIRECTOR          1972      1.0         8.1
# 51         10     Gary Andrews  DIRECTOR          1987     13.0         6.1
# 101        25     Yasunao Aoki  DIRECTOR          2000      9.0         7.9
# 102        25    Masashi Ikeda  DIRECTOR          2000      9.0         7.9
# 136        40   Bruno Stagnaro  DIRECTOR          2000      1.0         9.0
# ...       ...              ...       ...           ...      ...         ...
# 8381      110               --        --          2021      1.0         7.1
# 8382       38               --        --          2021      1.0         6.1
# 8383       43               --        --          2021      1.0         7.4
# 8384       26               --        --          2021      1.0         5.5
# 8385       33               --        --          2021      1.0         6.1
#
# [1299 rows x 13 columns]

# %%
netflix_df = netflix_df[['id', 'title', 'type', 'age_certification', 'runtime', 'release_year', \
                         'seasons', 'imdb_score']]
netflix_df = netflix_df.fillna({"name": '--',
                                "role": '--',
                                "seasons": 0})
netflix_df = netflix_df.drop_duplicates()
# netflix_df = netflix_df[netflix_df['imdb_score'] > 6.5]
# netflix_df = netflix_df[netflix_df['imdb_votes'] > 10000]
netflix_df
# Out:
#               id                               title   type age_certification  \
# 36       tm84618                         Taxi Driver  MOVIE                 R
# 59      tm154986                         Deliverance  MOVIE                 R
# 106     tm127384     Monty Python and the Holy Grail  MOVIE                PG
# 162     tm120801                     The Dirty Dozen  MOVIE               NaN
# 189      tm70993                       Life of Brian  MOVIE                 R
# ...          ...                                 ...    ...               ...
# 78154  tm1099342                     Devdas Brothers  MOVIE               NaN
# 78155   ts273317                       Pitta Kathalu   SHOW             TV-MA
# 78157  tm1066324   Super Monsters: Once Upon a Rhyme  MOVIE               NaN
# 78159   tm898842                         C/O Kaadhal  MOVIE               NaN
# 78161   ts271048  Mighty Little Bheem: Kite Festival   SHOW               NaN
#
#        runtime  release_year  seasons  imdb_score
# 36         114          1976      0.0         8.2
# 59         109          1972      0.0         7.7
# 106         91          1975      0.0         8.2
# 162        150          1967      0.0         7.7
# 189         94          1979      0.0         8.0
# ...        ...           ...      ...         ...
# 78154       99          2021      0.0         3.3
# 78155       37          2021      1.0         5.1
# 78157       25          2021      0.0         5.6
# 78159      134          2021      0.0         7.7
# 78161        7          2021      1.0         7.8
#
# [4018 rows x 8 columns]

# %%
hulu_df = hulu_df[['id', 'title', 'type', 'age_certification', 'runtime', 'release_year', \
                   'seasons', 'imdb_score']]
hulu_df = hulu_df.fillna({"name": '--',
                    "character": '--',
                    "role": '--',
                    "seasons": 0})
hulu_df = hulu_df.drop_duplicates()
# hulu_df = hulu_df[hulu_df['imdb_score'] > 6.5]
# hulu_df = hulu_df[hulu_df['imdb_votes'] > 10000]
hulu_df
# Out:
#              id                      title   type age_certification  runtime  \
# 81     tm147043                  The Lorax  MOVIE                PG       25
# 95       tm1236  A Boy Named Charlie Brown  MOVIE                 G       86
# 107    tm156894          Snoopy, Come Home  MOVIE                 G       81
# 115     tm11186         The Cat in the Hat  MOVIE               NaN       25
# 120    tm189299     Dr. Seuss on the Loose  MOVIE               NaN       25
# ...         ...                        ...    ...               ...      ...
# 31962  ts273453           Soul of a Nation   SHOW             TV-PG       41
# 31963  tm813666                Rising Wolf  MOVIE               NaN      102
# 31966  ts318346           Peckham's Finest   SHOW               NaN       33
# 31967  ts276887                   Swan Boy   SHOW               NaN        4
# 31968  ts330888        Roman to the Rescue   SHOW               NaN       24
#
#        release_year  seasons  imdb_score
# 81             1972      0.0         7.9
# 95             1969      0.0         7.3
# 107            1972      0.0         7.4
# 115            1971      0.0         7.3
# 120            1973      0.0         7.7
# ...             ...      ...         ...
# 31962          2021      1.0         4.9
# 31963          2021      0.0         3.5
# 31966          2021      1.0         5.4
# 31967          2021      1.0         8.4
# 31968          2021      1.0         7.0
#
# [1230 rows x 8 columns]

# %%
hbo_df = hbo_df[['id', 'title', 'type', 'age_certification', 'runtime', 'release_year', \
                 'seasons', 'imdb_score']]
hbo_df = hbo_df.fillna({"name": '--',
                    "character": '--',
                    "role": '--',
                    "seasons": 0})
hbo_df = hbo_df.drop_duplicates()
# hbo_df = hbo_df[hbo_df['imdb_score'] > 6.5]
# hbo_df = hbo_df[hbo_df['imdb_votes'] > 10000]
hbo_df
# Out:
#              id                                         title   type  \
# 22     tm155702                              The Wizard of Oz  MOVIE
# 175     tm83648                                  Citizen Kane  MOVIE
# 281     tm77588                                    Casablanca  MOVIE
# 328     tm82363                                 The Big Sleep  MOVIE
# 351     tm84701                            The Maltese Falcon  MOVIE
# ...         ...                                           ...    ...
# 66553  ts304558                     NYC Epicenters 9/11➔2021½   SHOW
# 66556  ts320289                              40 Means Nothing   SHOW
# 66557  ts314732  Dolores: The Truth About the Wanninkhof Case   SHOW
# 66558  ts309677                           Level Playing Field   SHOW
# 66561  ts300392                              Through Our Eyes   SHOW
#
#       age_certification  runtime  release_year  seasons  imdb_score
# 22                    G      102          1939      0.0         8.1
# 175                  PG      119          1941      0.0         8.3
# 281                  PG      102          1942      0.0         8.5
# 328                 NaN      116          1946      0.0         7.9
# 351                 NaN      100          1941      0.0         8.0
# ...                 ...      ...           ...      ...         ...
# 66553             TV-MA      110          2021      1.0         7.1
# 66556               NaN       38          2021      1.0         6.1
# 66557             TV-14       43          2021      1.0         7.4
# 66558             TV-14       26          2021      1.0         5.5
# 66561               NaN       33          2021      1.0         6.1
#
# [2339 rows x 8 columns]

# %%
#export csv's to resources folder
from pathlib import Path
filepath = Path("Output/movie_df.csv")
filepath.parent.mkdir(parents=True, exist_ok=True)
movie_df.to_csv(filepath)

filepath2 = Path("Output/show_df.csv")
filepath.parent.mkdir(parents=True, exist_ok=True)
show_df.to_csv(filepath2)

filepath3 = Path("Output/netflix_df.csv")
filepath.parent.mkdir(parents=True, exist_ok=True)
netflix_df.to_csv(filepath3)

filepath4 = Path("Output/hulu_df.csv")
filepath.parent.mkdir(parents=True, exist_ok=True)
hulu_df.to_csv(filepath4)

filepath5 = Path("Output/hbo_df.csv")
filepath.parent.mkdir(parents=True, exist_ok=True)
hbo_df.to_csv(filepath5)
