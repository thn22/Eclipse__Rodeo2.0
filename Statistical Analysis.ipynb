# %%
# Import dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import linregress
import scipy.stats as stats

# %%
# Load in csv for movies
cleaned_movie = pd.read_csv("Output/movie_df.csv")
# Delete Unnamed: 0 column
del cleaned_movie["Unnamed: 0"]
cleaned_movie = cleaned_movie.drop_duplicates()
#cleaned_movie

# %%
# Load in csv for TV shows
cleaned_tv = pd.read_csv("Output/show_df.csv")
# Delete Unnamed: 0 column
del cleaned_tv["Unnamed: 0"]
cleaned_tv = cleaned_tv.drop_duplicates()
#cleaned_tv

# %%
# Load in Netflix dataframe
netflix_df = pd.read_csv("Output/netflix_df.csv")
# Delete Unnamed: 0 column
del netflix_df["Unnamed: 0"]
netflix_df = netflix_df.drop_duplicates()
#netflix_df

# %%
# Load in Hulu dataframe
hulu_df = pd.read_csv("Output/hulu_df.csv")
#Delete Unnamed: 0 column
del hulu_df["Unnamed: 0"]
hulu_df = hulu_df.drop_duplicates()
#hulu_df

# %%
# Load in HBO dataframe
hbo_df = pd.read_csv("Output/hbo_df.csv")
#Delete Unnamed: 0 column
del hbo_df["Unnamed: 0"]
hbo_df = hbo_df.drop_duplicates()
#hbo_df

# %% [markdown]
# ## 1. Which director with 5 or more movies has the highest average rating?

# %%
#Filter the dataframe for all directors
director_df = cleaned_movie[cleaned_movie["role"]=="DIRECTOR"]
#director_df

# %%
#use groupby to match director with avg imdb score
group_director = director_df.groupby("name")
avg_score = group_director.mean().reset_index()
avg_score = avg_score[["name","imdb_score"]]
#avg_score

# %%
# Use previous dataframe to get the number of movies each director has made
director_movie = group_director.count().reset_index()
director_movie = director_movie[["name","title"]]
#director_movie

# %%
# Merge the two dataframes together and filter out directors with less than 4 movies
final_director = pd.merge(director_movie, avg_score, how="outer", on=["name"])
final_director = final_director[final_director["title"]>4]
final_director = final_director[final_director["imdb_score"]>7.4]
final_director = final_director[["name","imdb_score"]]
final_director = final_director.sort_values("imdb_score",ascending=False)

# %%
#create bar graph displaying director scores
x_axis = final_director["name"]
plt.figure(figsize=(22,6))
plt.bar(final_director["name"],final_director["imdb_score"],color="steelblue")
plt.xticks(rotation=90)
plt.title("Average IMDb score for Directors")
plt.xlabel("Directors (movies >= 5)")
plt.ylabel("IMDb Score")
print(f"{final_director.iloc[0,0]} has the highest average IMDb score with: {final_director.max(numeric_only=True).max()}")
plt.xlim(-1, len(x_axis))
plt.tight_layout()
plt.savefig("Output/director_score.png")
plt.show()
# Out:
# Akira Kurosawa has the highest average IMDb score with: 8.166666666666664

# %%
#filter dataframe to show Akira Kurosawa's movies
akira_df = cleaned_movie[cleaned_movie["name"]=="Akira Kurosawa"]
akira_df = akira_df.sort_values("imdb_score", ascending=False)
akira_df.reset_index()
# Out:
#    index        id  Netflix  Hulu  HBO                title   type  \
# 0   4896   tm18043      0.0   0.0  1.0        Seven Samurai  MOVIE
# 1   4917   tm32149      0.0   0.0  1.0         High and Low  MOVIE
# 2   4954   tm65430      0.0   0.0  1.0                Ikiru  MOVIE
# 3   4960   tm81379      0.0   0.0  1.0            Red Beard  MOVIE
# 4   4716   tm58806      0.0   0.0  1.0             Rashomon  MOVIE
# 5   4920   tm41864      0.0   0.0  1.0              Yojimbo  MOVIE
# 6   4956  tm119925      0.0   0.0  1.0      Throne of Blood  MOVIE
# 7   4972  tm127957      0.0   0.0  1.0  The Hidden Fortress  MOVIE
# 8   5075  tm104934      0.0   0.0  1.0         Dodes'ka-den  MOVIE
#
#   age_certification  runtime            name      role  release_year  seasons  \
# 0               NaN      207  Akira Kurosawa  DIRECTOR          1954      0.0
# 1               NaN      143  Akira Kurosawa  DIRECTOR          1963      0.0
# 2               NaN      143  Akira Kurosawa  DIRECTOR          1952      0.0
# 3               NaN      185  Akira Kurosawa  DIRECTOR          1965      0.0
# 4               NaN       88  Akira Kurosawa  DIRECTOR          1950      0.0
# 5               NaN      110  Akira Kurosawa  DIRECTOR          1961      0.0
# 6               NaN      108  Akira Kurosawa  DIRECTOR          1957      0.0
# 7               NaN      139  Akira Kurosawa  DIRECTOR          1958      0.0
# 8               NaN      140  Akira Kurosawa  DIRECTOR          1970      0.0
#
#    imdb_score
# 0         8.6
# 1         8.4
# 2         8.3
# 3         8.3
# 4         8.2
# 5         8.2
# 6         8.1
# 7         8.1
# 8         7.3

# %% [markdown]
# ### Which movie directed by Akria Kurosawa has the highest IMDb score?

# %%
#create bar graph that shows Akira Kurosawa's movies and their scores
plt.bar(akira_df["title"],akira_df["imdb_score"],color="steelblue")
plt.xticks(rotation=90)
plt.title("Akira Kurosawa's Movie Scores")
plt.xlabel("Movie Title")
plt.ylabel("IMDb Score")
plt.tight_layout()
plt.savefig("Output/kurosawa_score.png")
plt.show()
print(f"{akira_df.iloc[0,4]} is {akira_df.iloc[0,8]}'s highest scoring film.")
# Out:
# Seven Samurai is Akira Kurosawa's highest scoring film.

# %%
seven = director_df[director_df["title"]=="Seven Samurai"]
print(f"{seven.iloc[0, 4]} can be streamed on HBO.")
# Out:
# Seven Samurai can be streamed on HBO.

# %% [markdown]
# ## 2. Is there a correlation between number of seasons for a TV show and IMDb score?

# %%
# Create scatter plot that shows the number of seasons for each show relative to its IMDb score
x_value = cleaned_tv["seasons"]
y_value = cleaned_tv["imdb_score"]
plt.figure(figsize=(10,5))
plt.scatter(x_value,y_value, marker="o", color="lightsteelblue", edgecolors="steelblue")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value,y_value)
regression_value = x_value * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_value,regression_value,"darkblue",linewidth=2)
plt.grid(b=True,which="major",axis="both")
plt.annotate(line_equation,(12,2),color="darkblue",fontsize=16)
plt.title("TV Show IMDb score vs. Number of Seasons")
plt.xlabel("Number of Seasons")
plt.ylabel("IMDb Score")
plt.xlim(0, max(x_value)+2)
print(f"The r value is: {round(rvalue,2)}")
plt.savefig("Output/seasons_vs_score.png")
plt.show()
# Out:
# The r value is: 0.01

# %% [markdown]
# ### Which TV show with less than 10 seasons has the highest IMDb score? More than 10 seasons?

# %%
#filter the dataframe for highest rated TV shows over and under 10 seasons
final_tv = cleaned_tv[["title", "seasons", "imdb_score"]]
final_tv.reset_index()
final_tv = final_tv.sort_values("imdb_score", ascending=False)
final_tv = final_tv.head(2)
final_tv
# Out:
#         title  seasons  imdb_score
# 692  #ABtalks      1.0         9.6
# 614  Khawatir     11.0         9.5

# %%
#Create bar graph to show the highest rated TV shows over and under 10 seasons
plt.bar(final_tv["title"],final_tv["seasons"], color="steelblue")
plt.title("Top TV shows with IMDb score over 9.5")
plt.xlabel("TV Show titles")
plt.ylabel("Number of Seasons")
plt.tight_layout()
plt.savefig("Output/tvshows.png")
plt.show()

# %% [markdown]
# ## 3. Is there a correlation between movie run times and IMDb score?

# %%
#score vs. movie runtime graph
x_value = cleaned_movie["runtime"]
y_value = cleaned_movie["imdb_score"]
plt.figure(figsize=(10,5))
plt.scatter(x_value,y_value, marker="o", color="lightsteelblue", edgecolors="steelblue")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value,y_value)
regression_value = x_value * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_value,regression_value,"darkblue",linewidth=2)
plt.grid(b=True,which="major",axis="both")
plt.annotate(line_equation,(150,3),color="darkblue",fontsize=16)
print(f"The r value is: {round(rvalue,2)}")
plt.title("Movie Runtime vs. IMDb scores")
plt.xlabel("Runtime (mins)")
plt.ylabel("IMDb Score")
plt.savefig("Output/runtime_vs_score.png")
plt.show()
# Out:
# The r value is: 0.14

# %%
#filter the dataframe for highest rated movies over and under 120 minutes of runtime
final_movie = cleaned_movie.sort_values("imdb_score", ascending=False)
final_movie = final_movie[["title", "runtime", "imdb_score"]].head(2)
final_movie
# Out:
#                          title  runtime  imdb_score
# 5389  The Shawshank Redemption      142         9.3
# 7073         Emergency Contact       54         9.2

# %% [markdown]
# ### Which movie with a runtime longer than 120 minutes has the highest IMDb score? Less than 120 minutes?

# %%
#Create bar graph to show the highest rated movies over and under 120 minutes of runtime
plt.bar(final_movie["title"],final_movie["runtime"], color="steelblue")
plt.title("Top Movies with IMDb score over 9.2")
plt.xlabel("Movie Titles")
plt.ylabel("Runtime (min)")
plt.tight_layout()
plt.savefig("Output/top_movies_runtime.png")
plt.show()

# %% [markdown]
# ## 4. Which streaming service is most catered towards adults? Which is best for children?

# %% [markdown]
# ### Movie Ratings:

# %%
# Create a df for Netflix movie ratings to display the Age Certification and Counts
netflix_movie_ratings = netflix_df[netflix_df.type=="MOVIE"]
netflix_movie_ratings = netflix_movie_ratings['age_certification'].value_counts()
netflix_movie_ratings = pd.DataFrame(netflix_movie_ratings).reset_index().rename(columns={"index":"rating", "age_certification":"count"}).sort_values("rating")
#netflix_movie_ratings

# %%
# Create a df for Hulu movie ratings to display the Age Certification and Counts
hulu_movie_ratings = hulu_df[hulu_df.type=="MOVIE"]
hulu_movie_ratings = hulu_movie_ratings['age_certification'].value_counts()
hulu_movie_ratings = pd.DataFrame(hulu_movie_ratings).reset_index().rename(columns={"index":"rating", "age_certification":"count"}).sort_values("rating")
#hulu_movie_ratings

# %%
# Create a df for HBO movie ratings to display the Age Certification and Counts
hbo_movie_ratings = hbo_df[hbo_df.type=="MOVIE"]
hbo_movie_ratings = hbo_movie_ratings['age_certification'].value_counts()
hbo_movie_ratings = pd.DataFrame(hbo_movie_ratings).reset_index().rename(columns={"index":"rating", "age_certification":"count"}).sort_values("rating")
#hbo_movie_ratings

# %%
# Display movie rating df for each streaming service to create lists to plot
#netflix_movie_ratings
#hulu_movie_ratings
hbo_movie_ratings
# Out:
#   rating  count
# 3      G     71
# 4  NC-17      7
# 2     PG    264
# 1  PG-13    430
# 0      R    576

# %%
# Create bar graphs comparing age certifications within each streaming service
## Code adapted from https://www.geeksforgeeks.org/create-a-grouped-bar-plot-in-matplotlib/
ratings_m = ["G", "PG", "PG-13", "R", "NC-17"]
y1 = [91, 221, 420, 525, 15]
y2 = [31, 80, 136, 298, 2]
y3 = [71, 264, 430, 576, 7]
x = np.arange(len(ratings_m))
width = 0.2
plt.figure(figsize=(10,4))
plt.bar(x - 0.2, y1, width, color="crimson")
plt.bar(x, y2, width, color="limegreen")
plt.bar(x + 0.2, y3, width, color="blueviolet")
plt.xticks(x, ["G", "PG", "PG-13", "R", "NC-17"])
plt.title("Ratings Distribution for Each Streaming Service")
plt.xlabel("Movie Ratings")
plt.ylabel("Number of Movies")
plt.legend(["Netflix", "Hulu", "HBO"])
plt.grid(b=True,which="major",axis="y")
plt.savefig("Output/movie_ratings_vs_service.png")
plt.show()

# %% [markdown]
# ### Is there statistical significance between the streaming service and age ratings?

# %%
# Create a df to perform a chi square analysis for movie ratings
d = {"Netflix":y1, "Hulu":y2, "HBO":y3}
movie_cv = pd.DataFrame(data=d, index=ratings_m)
movie_cv["Total"]=movie_cv.sum(axis=1)
movie_cv["Expected"]=round(movie_cv["Total"]/3,0)
movie_cv
# Out:
#        Netflix  Hulu  HBO  Total  Expected
# G           91    31   71    193      64.0
# PG         221    80  264    565     188.0
# PG-13      420   136  430    986     329.0
# R          525   298  576   1399     466.0
# NC-17       15     2    7     24       8.0

# %%
# Complete Chi Square test for each rating across each streaming service
# Since there are three streaming services, the degree of freedom is 2 (3-1=2)
# With a p-value of 0.05, the confidence level is 1.00-0.05 = 0.95
critical_value = stats.chi2.ppf(q=0.95, df=2)
critical_value
# Out:
# 5.991464547107979

# %%
# Run the test for each age certification & print results
g_rating = stats.chisquare(movie_cv.iloc[0, 0:3], movie_cv.iloc[0,4])
pg_rating = stats.chisquare(movie_cv.iloc[1, 0:3], movie_cv.iloc[1,4])
pg13_rating = stats.chisquare(movie_cv.iloc[2, 0:3], movie_cv.iloc[2,4])
r_rating = stats.chisquare(movie_cv.iloc[3, 0:3], movie_cv.iloc[3,4])
nc17_rating = stats.chisquare(movie_cv.iloc[4, 0:3], movie_cv.iloc[4,4])
print(f'''G: {g_rating}
PG: {pg_rating}
PG-13: {pg13_rating}
R: {r_rating}
NC-17: {nc17_rating}''')
# Out:
# G: Power_divergenceResult(statistic=29.171875, pvalue=4.6281543076216607e-07)
# PG: Power_divergenceResult(statistic=98.55851063829788, pvalue=3.965439630396679e-22)
# PG-13: Power_divergenceResult(statistic=169.3951367781155, pvalue=1.6455588479509451e-37)
# R: Power_divergenceResult(statistic=94.00214592274679, pvalue=3.869843208035974e-21)
# NC-17: Power_divergenceResult(statistic=10.75, pvalue=0.004630918733533247)

# %% [markdown]
# ### TV Show Ratings:

# %%
# Create a df for Netflix TV ratings to display the Age Certification and Counts
netflix_tv_ratings = netflix_df[netflix_df.type=="SHOW"]
netflix_tv_ratings = netflix_tv_ratings['age_certification'].value_counts()
netflix_tv_ratings = pd.DataFrame(netflix_tv_ratings).reset_index().rename(columns={"index":"rating", "age_certification":"count"}).sort_values("rating")
#netflix_tv_ratings

# %%
# Create a df for Hulu TV ratings to display the Age Certification and Counts
hulu_tv_ratings = hulu_df[hulu_df.type=="SHOW"]
hulu_tv_ratings = hulu_tv_ratings['age_certification'].value_counts()
hulu_tv_ratings = pd.DataFrame(hulu_tv_ratings).reset_index().rename(columns={"index":"rating", "age_certification":"count"}).sort_values("rating")
#hulu_tv_ratings

# %%
# Create a df for HBO TV ratings to display the Age Certification and Counts
hbo_tv_ratings = hbo_df[hbo_df.type=="SHOW"]
hbo_tv_ratings = hbo_tv_ratings['age_certification'].value_counts()
hbo_tv_ratings = pd.DataFrame(hbo_tv_ratings).reset_index().rename(columns={"index":"rating", "age_certification":"count"}).sort_values("rating")
#hbo_tv_ratings

# %%
# Display TV rating df for each streaming service to create lists to plot
#netflix_tv_ratings
hulu_tv_ratings
#hbo_tv_ratings
# Out:
#   rating  count
# 0  TV-14    105
# 4   TV-G      6
# 1  TV-MA     43
# 2  TV-PG     25
# 5   TV-Y      4
# 3  TV-Y7     12

# %%
# Create bar graphs showing correlation between number of seasons for a TV show and IMDb score
ratings_s = ["TV-Y", "TV-G", "TV-Y7", "TV-PG", "TV-14", "TV-MA"]
y1 = [46, 12, 24, 52, 164, 290]
y2 = [4, 6, 12, 25, 105, 43]
y3 = [4, 5, 1, 14, 29, 40]
x = np.arange(len(ratings_s))
width = 0.2
plt.figure(figsize=(12,5))
plt.bar(x - 0.2, y1, width, color="crimson")
plt.bar(x, y2, width, color="limegreen")
plt.bar(x + 0.2, y3, width, color="blueviolet")
plt.xticks(x, ["TV-Y", "TV-G", "TV-Y7", "TV-PG", "TV-14", "TV-MA", "NC-17"])
plt.title("Ratings Distribution for Each Streaming Service")
plt.xlabel("Show Ratings")
plt.ylabel("Number of Shows")
plt.legend(["Netflix", "Hulu", "HBO"])
plt.grid(b=True,which="major",axis="y")
plt.savefig("Output/tv_ratings_vs_service.png")
plt.show()

# %% [markdown]
# ### Is there statistical significance between the streaming service and age ratings?

# %%
# Create a df to perform a chi square analysis for TV ratings
d = {"Netflix":y1, "Hulu":y2, "HBO":y3}
show_cv = pd.DataFrame(data=d, index=ratings_s)
show_cv["Total"]=show_cv.sum(axis=1)
show_cv["Expected"]=round(show_cv["Total"]/3,0)
show_cv
# Out:
#        Netflix  Hulu  HBO  Total  Expected
# TV-Y        46     4    4     54      18.0
# TV-G        12     6    5     23       8.0
# TV-Y7       24    12    1     37      12.0
# TV-PG       52    25   14     91      30.0
# TV-14      164   105   29    298      99.0
# TV-MA      290    43   40    373     124.0

# %%
# Complete Chi Square test for each rating across each streaming service
# Since there are three streaming services, the degree of freedom is 2 (3-1=2)
# With a p-value of 0.05, the confidence level is 1.00-0.05 = 0.95
critical_value = stats.chi2.ppf(q=0.95, df=2)
critical_value
# Out:
# 5.991464547107979

# %%
# Run the test for each age certification & print results
tvy_rating = stats.chisquare(show_cv.iloc[0, 0:3], show_cv.iloc[0,4])
tvg_rating = stats.chisquare(show_cv.iloc[1, 0:3], show_cv.iloc[1,4])
tvy7_rating = stats.chisquare(show_cv.iloc[2, 0:3], show_cv.iloc[2,4])
tvpg_rating = stats.chisquare(show_cv.iloc[3, 0:3], show_cv.iloc[3,4])
tv14_rating = stats.chisquare(show_cv.iloc[4, 0:3], show_cv.iloc[4,4])
tvma_rating = stats.chisquare(show_cv.iloc[5, 0:3], show_cv.iloc[5,4])
print(f'''TV-Y: {tvy_rating}
TV-G: {tvg_rating}
TV-Y7: {tvy7_rating }
TV-PG: {tvpg_rating}
TV-14: {tv14_rating}
TV-MA: {tvma_rating}''')
# Out:
# TV-Y: Power_divergenceResult(statistic=65.33333333333333, pvalue=6.5019993911677576e-15)
# TV-G: Power_divergenceResult(statistic=3.625, pvalue=0.16324551245395838)
# TV-Y7: Power_divergenceResult(statistic=22.083333333333336, pvalue=1.602009531379498e-05)
# TV-PG: Power_divergenceResult(statistic=25.5, pvalue=2.9023204086504045e-06)
# TV-14: Power_divergenceResult(statistic=92.53535353535354, pvalue=8.057555198018144e-21)
# TV-MA: Power_divergenceResult(statistic=332.0403225806451, pvalue=7.91334439403947e-73)

# %% [markdown]
# ## 5. Do older movies have higher IMDb scores than newer movies?

# %%
#Filter the dataframe for in order of released year
cleaned_movie.sort_values("release_year",ascending=True)
# Out:
#              id  Netflix  Hulu  HBO                               title  \
# 4859    tm78145      0.0   0.0  1.0                       Shoulder Arms
# 4759   tm122846      0.0   0.0  1.0                             The Kid
# 4800    tm85292      0.0   0.0  1.0                 Nanook of the North
# 4877    tm89942      0.0   0.0  1.0                            Dr. Jack
# 4876    tm89942      0.0   0.0  1.0                            Dr. Jack
# ...         ...      ...   ...  ...                                 ...
# 2935  tm1229846      1.0   0.0  0.0                My Daughter's Killer
# 2936  tm1201262      1.0   0.0  0.0                       Love & Gelato
# 2937   tm852172      1.0   0.0  0.0  Apollo 10½:  A Space Age Childhood
# 6909  tm1142230      0.0   0.0  1.0                                Kimi
# 3157   tm855641      1.0   0.0  0.0                           Home2Home
#
#        type age_certification  runtime                name      role  \
# 4859  MOVIE               NaN       45     Charlie Chaplin  DIRECTOR
# 4759  MOVIE               NaN       53     Charlie Chaplin  DIRECTOR
# 4800  MOVIE               NaN       79  Robert J. Flaherty  DIRECTOR
# 4877  MOVIE               NaN       60          Sam Taylor  DIRECTOR
# 4876  MOVIE               NaN       60    Fred C. Newmeyer  DIRECTOR
# ...     ...               ...      ...                 ...       ...
# 2935  MOVIE                 R       83      Antoine Tassin  DIRECTOR
# 2936  MOVIE             PG-13      111        Brandon Camp  DIRECTOR
# 2937  MOVIE             PG-13       98   Richard Linklater  DIRECTOR
# 6909  MOVIE                 R       89   Steven Soderbergh  DIRECTOR
# 3157  MOVIE               NaN      110      Dennis Kailing  DIRECTOR
#
#       release_year  seasons  imdb_score
# 4859          1918      0.0         7.3
# 4759          1921      0.0         8.3
# 4800          1922      0.0         7.6
# 4877          1922      0.0         7.1
# 4876          1922      0.0         7.1
# ...            ...      ...         ...
# 2935          2022      0.0         6.9
# 2936          2022      0.0         5.1
# 2937          2022      0.0         7.3
# 6909          2022      0.0         6.3
# 3157          2022      0.0         7.9
#
# [7085 rows x 13 columns]

# %%
# Create a filtered dataframe with columns 'id', 'Netflix', 'Hulu', 'HBO', 'title',
#'type', 'age_certification', 'runtime', 'release_year', 'imdb_score'. By removing "role" and "name", we can drop
# any duplicates where there were multiple directors for one movie.
filtered_movie = cleaned_movie[['id', 'Netflix', 'Hulu', 'HBO', 'title', 'type', 'age_certification', 'runtime', 'release_year', 'imdb_score']]
filtered_movie = filtered_movie.drop_duplicates()
filtered_movie
# Out:
#             id  Netflix  Hulu  HBO                                     title  \
# 0      tm84618      1.0   0.0  0.0                               Taxi Driver
# 1     tm154986      1.0   0.0  0.0                               Deliverance
# 2     tm127384      1.0   0.0  0.0           Monty Python and the Holy Grail
# 4     tm120801      1.0   0.0  0.0                           The Dirty Dozen
# 5      tm70993      1.0   0.0  0.0                             Life of Brian
# ...        ...      ...   ...  ...                                       ...
# 7080  tm832366      0.0   0.0  1.0  Shakira in Concert: El Dorado World Tour
# 7081  tm949799      0.0   0.0  1.0                                Territorio
# 7082  tm825662      0.0   0.0  1.0                        Return to the Moon
# 7083  tm483047      0.0   0.0  1.0                                  Sterling
# 7084  tm962124      0.0   0.0  1.0                                 Habla Now
#
#        type age_certification  runtime  release_year  imdb_score
# 0     MOVIE                 R      114          1976         8.2
# 1     MOVIE                 R      109          1972         7.7
# 2     MOVIE                PG       91          1975         8.2
# 4     MOVIE               NaN      150          1967         7.7
# 5     MOVIE                 R       94          1979         8.0
# ...     ...               ...      ...           ...         ...
# 7080  MOVIE               NaN      122          2019         7.8
# 7081  MOVIE               NaN       94          2020         5.8
# 7082  MOVIE                PG        1          2019         8.0
# 7083  MOVIE               NaN       20          2019         7.3
# 7084  MOVIE               NaN       58          2020         6.2
#
# [6455 rows x 10 columns]

# %%
#Use scatter plot to show correlation between movie release year and IMDb score
x_value = filtered_movie["release_year"]
y_value = filtered_movie["imdb_score"]
plt.figure(figsize=(10,5))
plt.scatter(x_value,y_value, marker="o", color="lightsteelblue", edgecolors="steelblue")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value,y_value)
regression_value = x_value * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_value,regression_value,"darkblue",linewidth=2)
plt.grid(b=True,which="major",axis="both")
plt.annotate(line_equation,(1925,9),color="darkblue",fontsize=16)
plt.title("IMDb scores vs Release Year")
plt.xlabel("Year (1918-2022)")
plt.ylabel("IMDb Score")
print(f"The r value is: {round(rvalue,2)}")
plt.savefig("Output/year_vs_score.png")
plt.show()
# Out:
# The r value is: -0.28

# %%
#Filter the dataframe for movies released before 2005
filtered_old = filtered_movie[filtered_movie["release_year"]<2005]
filtered_old
# Out:
#             id  Netflix  Hulu  HBO                                     title  \
# 0      tm84618      1.0   0.0  0.0                               Taxi Driver
# 1     tm154986      1.0   0.0  0.0                               Deliverance
# 2     tm127384      1.0   0.0  0.0           Monty Python and the Holy Grail
# 4     tm120801      1.0   0.0  0.0                           The Dirty Dozen
# 5      tm70993      1.0   0.0  0.0                             Life of Brian
# ...        ...      ...   ...  ...                                       ...
# 6172  tm146332      0.0   0.0  1.0  Salt Lake 2002: Stories of Olympic Glory
# 6177  tm144406      0.0   0.0  1.0               Dennis Miller: The Raw Feed
# 6182  tm364871      0.0   0.0  1.0     Sydney 2000: Stories of Olympic Glory
# 7051  tm364104      0.0   0.0  1.0              The IX Olympiad in Amsterdam
# 7053  tm308754      0.0   0.0  1.0                                   The End
#
#        type age_certification  runtime  release_year  imdb_score
# 0     MOVIE                 R      114          1976         8.2
# 1     MOVIE                 R      109          1972         7.7
# 2     MOVIE                PG       91          1975         8.2
# 4     MOVIE               NaN      150          1967         7.7
# 5     MOVIE                 R       94          1979         8.0
# ...     ...               ...      ...           ...         ...
# 6172  MOVIE               NaN      120          2003         6.6
# 6177  MOVIE               NaN       60          2003         5.6
# 6182  MOVIE               NaN      116          2001         6.8
# 7051  MOVIE               NaN      251          1928         5.9
# 7053  MOVIE               NaN       84          2004         7.1
#
# [1411 rows x 10 columns]

# %%
#Filter the dataframe for movies released after 2005
filtered_new = filtered_movie[filtered_movie["release_year"]>=2005]
filtered_new
# Out:
#             id  Netflix  Hulu  HBO                                     title  \
# 175    tm74402      1.0   0.0  0.0                                  The Mist
# 180    tm92641      1.0   0.0  1.0                                 Inception
# 181    tm27911      1.0   0.0  0.0                              The Departed
# 182    tm88465      1.0   0.0  0.0                                 Insidious
# 183   tm172683      1.0   0.0  0.0                         War of the Worlds
# ...        ...      ...   ...  ...                                       ...
# 7080  tm832366      0.0   0.0  1.0  Shakira in Concert: El Dorado World Tour
# 7081  tm949799      0.0   0.0  1.0                                Territorio
# 7082  tm825662      0.0   0.0  1.0                        Return to the Moon
# 7083  tm483047      0.0   0.0  1.0                                  Sterling
# 7084  tm962124      0.0   0.0  1.0                                 Habla Now
#
#        type age_certification  runtime  release_year  imdb_score
# 175   MOVIE                 R      126          2007         7.1
# 180   MOVIE             PG-13      148          2010         8.8
# 181   MOVIE                 R      151          2006         8.5
# 182   MOVIE             PG-13      103          2010         6.8
# 183   MOVIE             PG-13      117          2005         6.5
# ...     ...               ...      ...           ...         ...
# 7080  MOVIE               NaN      122          2019         7.8
# 7081  MOVIE               NaN       94          2020         5.8
# 7082  MOVIE                PG        1          2019         8.0
# 7083  MOVIE               NaN       20          2019         7.3
# 7084  MOVIE               NaN       58          2020         6.2
#
# [5044 rows x 10 columns]

# %%
#Use scatter plot graph to show correlation between movies released before 2005 and IMDb scores
x_value = filtered_old["release_year"]
y_value = filtered_old["imdb_score"]
plt.figure(figsize=(10,5))
plt.scatter(x_value,y_value, marker="o", color="lightsteelblue", edgecolors="steelblue")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value,y_value)
regression_value = x_value * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_value,regression_value,"darkblue",linewidth=2)
plt.grid(b=True,which="major",axis="both")
plt.annotate(line_equation,(1925,9),color="darkblue",fontsize=16)
plt.title("IMDb scores vs Release Year for 'Old Movies'")
plt.xlabel("Year (1918-2004)")
plt.ylabel("IMDb Score")
plt.xlim(1919.5,2005)
print(f"The r value is: {round(rvalue,2)}")
plt.savefig("Output/old_release_vs_score.png")
plt.show()
print(f"Movie Count: {len(filtered_old)}")
# Out:
# The r value is: -0.27
# Movie Count: 1411

# %%
#Use scatter plot graph to show correlation between movies released after 2005 and IMDb scores
x_value = filtered_new["release_year"]
y_value = filtered_new["imdb_score"]
plt.figure(figsize=(10,5))
plt.scatter(x_value,y_value, marker="o", color="lightsteelblue", edgecolors="steelblue")
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_value,y_value)
regression_value = x_value * slope + intercept
line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_value,regression_value,"darkblue",linewidth=2)
plt.grid(b=True,which="major",axis="both")
plt.annotate(line_equation,(2007,8.6),color="darkblue",fontsize=16)
plt.title("IMDb scores vs Release Year for 'New Movies'")
plt.xlabel("Year (2005-2022)")
plt.ylabel("IMDb Score")
plt.xlim(2004.5,2022.5)
print(f"The r value is: {round(rvalue,2)}")
plt.savefig("Output/new_release_vs_score.png")
plt.show()
print(f"Movie Count: {len(filtered_new)}")
# Out:
# The r value is: -0.14
# Movie Count: 5044

# %%
#filter the dataframe for highest rated movies released before and after 2005
top_movies = filtered_movie.sort_values("imdb_score", ascending=False)
top_movies = top_movies[["title", "release_year", "imdb_score"]].head(2)
top_movies
# Out:
#                          title  release_year  imdb_score
# 5389  The Shawshank Redemption          1994         9.3
# 7073         Emergency Contact          2015         9.2

# %% [markdown]
# ### Which "old" movie has the highest IMDb score? "New" movie?

# %%
#Create bar graph to show the highest rated movies released before and after 2005
plt.bar(top_movies["title"],top_movies["release_year"], color="steelblue")
plt.title("Top Movies with IMDb score over 9.2")
plt.xlabel("Movie Titles")
plt.ylabel("Release Year")
plt.ylim(1900, 2022)
plt.savefig("Output/old_new_movies.png")
plt.show()
